# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd

# %%
# let's mount the google drive with the landmark information.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Let's set up some constants we will be using from hear on out
csv_path = '/content/drive/MyDrive/landmarks.csv'

# %%
df = pd.read_csv(csv_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131374 entries, 0 to 131373
# Data columns (total 43 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   1_X     131374 non-null  float64
#  1   1_Y     131374 non-null  float64
#  2   2_X     131374 non-null  float64
#  3   2_Y     131374 non-null  float64
#  4   3_X     131374 non-null  float64
#  5   3_Y     131374 non-null  float64
#  6   4_X     131374 non-null  float64
#  7   4_Y     131374 non-null  float64
#  8   5_X     131374 non-null  float64
#  9   5_Y     131374 non-null  float64
#  10  6_X     131374 non-null  float64
#  11  6_Y     131374 non-null  float64
#  12  7_X     131374 non-null  float64
#  13  7_Y     131374 non-null  float64
#  14  8_X     131374 non-null  float64
#  15  8_Y     131374 non-null  float64
#  16  9_X     131374 non-null  float64
#  17  9_Y     131374 non-null  float64
#  18  10_X    131374 non-null  float64
#  19  10_Y    131374 non-null  float64
#  20  11_X    131374 non-null  float64
#  21  11_Y    131374 non-null  float64
#  22  12_X    131374 non-null  float64
#  23  12_Y    131374 non-null  float64
#  24  13_X    131374 non-null  float64
#  25  13_Y    131374 non-null  float64
#  26  14_X    131374 non-null  float64
#  27  14_Y    131374 non-null  float64
#  28  15_X    131374 non-null  float64
#  29  15_Y    131374 non-null  float64
#  30  16_X    131374 non-null  float64
#  31  16_Y    131374 non-null  float64
#  32  17_X    131374 non-null  float64
#  33  17_Y    131374 non-null  float64
#  34  18_X    131374 non-null  float64
#  35  18_Y    131374 non-null  float64
#  36  19_X    131374 non-null  float64
#  37  19_Y    131374 non-null  float64
#  38  20_X    131374 non-null  float64
#  39  20_Y    131374 non-null  float64
#  40  21_X    131374 non-null  float64
#  41  21_Y    131374 non-null  float64
#  42  Label   131374 non-null  object
# dtypes: float64(42), object(1)
# memory usage: 43.1+ MB

# %%
df.describe()
# Out:
#                  1_X            1_Y            2_X            2_Y  \
# count  131374.000000  131374.000000  131374.000000  131374.000000
# mean        0.488086       0.918360       0.730125       0.810828
# std         0.307115       0.211884       0.216582       0.170798
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.256410       1.000000       0.613636       0.782609
# 50%         0.452830       1.000000       0.764706       0.854839
# 75%         0.717583       1.000000       0.901961       0.903614
# max         1.000000       1.000000       1.000000       1.000000
#
#                  3_X            3_Y            4_X            4_Y  \
# count  131374.000000  131374.000000  131374.000000  131374.000000
# mean        0.847635       0.637000       0.744350       0.503185
# std         0.178669       0.164749       0.205022       0.196958
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.746032       0.549020       0.611111       0.380952
# 50%         0.913462       0.658824       0.773333       0.507042
# 75%         1.000000       0.740000       0.926829       0.616279
# max         1.000000       1.000000       1.000000       1.000000
#
#                  5_X            5_Y  ...           17_X           17_Y  \
# count  131374.000000  131374.000000  ...  131374.000000  131374.000000
# mean        0.598465       0.435406  ...       0.418000       0.536184
# std         0.314724       0.247458  ...       0.236981       0.279268
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.336134       0.277778  ...       0.263158       0.384615
# 50%         0.535211       0.425287  ...       0.391304       0.621429
# 75%         0.973684       0.572650  ...       0.536585       0.714286
# max         1.000000       1.000000  ...       1.000000       1.000000
#
#                 18_X           18_Y           19_X           19_Y  \
# count  131374.000000  131374.000000  131374.000000  131374.000000
# mean        0.159143       0.508386       0.148734       0.411053
# std         0.202207       0.202968       0.175688       0.205101
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.375000       0.019608       0.255860
# 50%         0.055556       0.520000       0.081081       0.402985
# 75%         0.276786       0.644068       0.225806       0.561404
# max         1.000000       1.000000       1.000000       1.000000
#
#                 20_X           20_Y           21_X           21_Y
# count  131374.000000  131374.000000  131374.000000  131374.000000
# mean        0.213518       0.467926       0.256720       0.513604
# std         0.210121       0.239966       0.255719       0.295338
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.062500       0.283019       0.054545       0.245283
# 50%         0.139241       0.477612       0.177778       0.597015
# 75%         0.298507       0.658730       0.370690       0.747748
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_matrix = df.drop('Label', axis=1).corr()
sns.heatmap(corr_matrix, annot=False)
plt.show()

# %%
val_counts = df['Label'].value_counts()
val_counts
# Out:
# Label
# F    5798
# K    5464
# J    5264
# Y    5244
# S    5204
# R    5178
# L    5168
# V    5160
# D    5110
# U    5080
# G    5066
# W    4990
# H    4898
# I    4898
# Z    4844
# T    4772
# E    4678
# O    4670
# A    4542
# B    4478
# X    4418
# Q    4326
# P    4192
# C    4156
# s    3724
# d    3638
# M    3574
# N    2834
# n       6
# Name: count, dtype: int64

# %%
val_counts.plot.bar()
# Out:
# <Axes: xlabel='Label'>

# %% [markdown]
# The dataset is not as balanced as initially thought. It may be that there are not as many observations in the folders or it may be that errors occurred while communicating with Google to retrieve the vectors. Either way, there may be difficulty signing nothing (n) because of only 6 observations compared to the other gestures which have over 2000 examples.
#
# We may have to regeneate the data to compensate for the missing data.
